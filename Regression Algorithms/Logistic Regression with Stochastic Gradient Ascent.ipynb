# %% [markdown]
# # Training Logistic Regression via Stochastic Gradient Ascent
#
# The goal of this notebook is to implement a logistic regression classifier using stochastic gradient ascent.
# We will:
#
#  * Extract features from Amazon product reviews.
#  * Convert an SFrame into a NumPy array.
#  * Write a function to compute the derivative of log likelihood function with respect to a single coefficient.
#  * Implement stochastic gradient ascent.
#  * Compare convergence of stochastic gradient ascent with that of batch gradient ascent.

# %% [markdown]
# # Fire up Turi Create
#
# Make sure you have the latest version of Turi Create.

# %%
from __future__ import division
import turicreate
import os
import numpy as np
import math
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load and process Amazons review dataset

# %% [markdown]
# For this notebook we will use a dataset consisting of Amazon product reviews. The subset was chosen to contain similar numbers of positive and negative reviews, as the original dataset consisted of mostly positive reviews.

# %%
products=turicreate.SFrame(r'amazon_baby_subset.csv')
# Out:
# Finished parsing file /home/ian/venv/UWashington_MachineLearningSpecialization/Notebooks/GitHub/GitHub Data/Edited/amazon_baby_subset.csv
# Parsing completed. Parsed 100 lines in 0.16646 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/ian/venv/UWashington_MachineLearningSpecialization/Notebooks/GitHub/GitHub Data/Edited/amazon_baby_subset.csv
# Parsing completed. Parsed 49999 lines in 0.231553 secs.

# %% [markdown]
# We will work with a hand-curated list of important words extracted from the review data. We will also perform 2 simple data transformations:
#
# 1. Remove punctuation using [Python's built-in](https://docs.python.org/2/library/string.html) string manipulation functionality.
# 2. Compute word counts (only for the important_words)
#
# Refer to Module 3 assignment for more details.

# %%
import json
import string
with open('important_words.json', 'r') as f: 
    important_words = json.load(f)
important_words = [str(s) for s in important_words]

# Remove punctuation
def remove_punctuation(text):
    try: # python 2.x
        text = text.translate(None, string.punctuation) 
    except: # python 3.x
        translator = text.maketrans('', '', string.punctuation)
        text = text.translate(translator)
    return text

products['review_clean'] = products['review'].apply(remove_punctuation)

# Split out the words into individual columns
for word in important_words:
    products[word] = products['review_clean'].apply(lambda s : s.split().count(word))

# %% [markdown]
# The SFrame **products** now contains one column for each of the 193 **important_words**.

# %% [markdown]
# ### Split data into training and validation sets
#
# We will now split the data into a 90-10 split where 90% is in the training set and 10% is in the validation set. We use `seed=1` so that we can reproduce the same result.

# %%
train_data, validation_data = products.random_split(.9, seed=1)

print('Training set  : %d data points' % len(train_data))
print('Validation set: %d data points' % len(validation_data))
# Out:
# Training set  : 45022 data points
# Validation set: 4977 data points

# %% [markdown]
# ## Convert SFrame to NumPy array
#
# We use a function that extracts columns from an SFrame and converts them into a NumPy array. Two arrays are returned: one representing features and another representing class labels.
#
# **Note:** The feature matrix includes an additional column 'intercept' filled with 1's to take account of the intercept term.

# %%
def get_numpy_data(data_sframe, features, label):
    data_sframe['intercept'] = 1
    features = ['intercept'] + features
    features_sframe = data_sframe[features]
    feature_matrix = features_sframe.to_numpy()
    label_sarray = data_sframe[label]
    label_array = label_sarray.to_numpy()
    return(feature_matrix, label_array)

# %% [markdown]
# Note that we convert both the training and validation sets into NumPy arrays.

# %%
feature_matrix_train, sentiment_train = get_numpy_data(train_data, important_words, 'sentiment')
feature_matrix_valid, sentiment_valid = get_numpy_data(validation_data, important_words, 'sentiment')

# %% [markdown]
# ## Building on logistic regression
#
# Recall that the link function for logistic regression can be defined as:
#
# $$
# P(y_i = +1 | \mathbf{x}_i,\mathbf{w}) = \frac{1}{1 + \exp(-\mathbf{w}^T h(\mathbf{x}_i))},
# $$
#
# where the feature vector $h(\mathbf{x}_i)$ is given by the word counts of **important_words** in the review $\mathbf{x}_i$.
#
#
# We define a function to make probability predictions:

# %%
'''
produces probablistic estimate for P(y_i = +1 | x_i, w).
estimate ranges between 0 and 1.
'''
def predict_probability(feature_matrix, coefficients):
    # Take dot product of feature_matrix and coefficients  
    score = np.dot(feature_matrix, coefficients)
    
    # Compute P(y_i = +1 | x_i, w) using the link function
    predictions = 1. / (1.+np.exp(-score))    
    return predictions

# %% [markdown]
# ## Derivative of log likelihood with respect to a single coefficient
#
# Let us now work on making minor changes to how the derivative computation is performed for logistic regression.
#
# Recall that for logistic regression, **the derivative of log likelihood with respect to a single coefficient** is as follows:
#
# $$
# \frac{\partial\ell}{\partial w_j} = \sum_{i=1}^N h_j(\mathbf{x}_i)\left(\mathbf{1}[y_i = +1] - P(y_i = +1 | \mathbf{x}_i, \mathbf{w})\right)
# $$

# %%
def feature_derivative(errors, feature): 
    
    # Compute the dot product of errors and feature
    derivative = np.dot(errors, feature)

    return derivative

# %% [markdown]
# **Note**. We are not using regularization in this notebook, but stochastic gradient can also be used for regularized logistic regression.

# %% [markdown]
# To track the performance of stochastic gradient ascent we define a fucntion for computing **average log likelihood**:
#
# $$\ell\ell_A(\mathbf{w}) = \color{red}{\frac{1}{N}} \sum_{i=1}^N \Big( (\mathbf{1}[y_i = +1] - 1)\mathbf{w}^T h(\mathbf{x}_i) - \ln\left(1 + \exp(-\mathbf{w}^T h(\mathbf{x}_i))\right) \Big) $$

# %%
def compute_avg_log_likelihood(feature_matrix, sentiment, coefficients):
    
    indicator = (sentiment==+1)
    scores = np.dot(feature_matrix, coefficients)
    logexp = np.log(1. + np.exp(-scores))
    
    # Simple check to prevent overflow
    mask = np.isinf(logexp)
    logexp[mask] = -scores[mask]
    
    lp = np.sum((indicator-1)*scores - logexp)/len(feature_matrix)
    
    return lp

# %% [markdown]
# ## Modifying the derivative for stochastic gradient ascent
#
# Recall that the gradient for a single data point $\color{red}{\mathbf{x}_i}$ can be computed using the following formula:
#
# $$
# \frac{\partial\ell_{\color{red}{i}}(\mathbf{w})}{\partial w_j} = h_j(\color{red}{\mathbf{x}_i})\left(\mathbf{1}[y_\color{red}{i} = +1] - P(y_\color{red}{i} = +1 | \color{red}{\mathbf{x}_i}, \mathbf{w})\right)
# $$
#
# We compute $\partial\ell_{\color{red}{i}}(\mathbf{w})/\partial w_j$ using the following steps:
# * First, we compute $P(y_i = +1 | \mathbf{x}_i, \mathbf{w})$ using the **predict_probability** function with `feature_matrix_train[i:i+1,:]` as the first parameter.
# * Next, we compute $\mathbf{1}[y_i = +1]$ using `sentiment_train[i:i+1]`.
# * Finally, call the **feature_derivative** function with `feature_matrix_train[i:i+1, j]` as one of the parameters.
#
# Let us follow these steps for `j = 1` and `i = 10`:

# %%
j = 1                        # Feature number
i = 10                       # Data point number
coefficients = np.zeros(194) # A point w at which we are computing the gradient.

predictions = predict_probability(feature_matrix_train[i:i+1,:], coefficients)
indicator = (sentiment_train[i:i+1]==+1)

errors = indicator - predictions        
gradient_single_data_point = feature_derivative(errors, feature_matrix_train[i:i+1,j])
print "Gradient single data point: %s" % gradient_single_data_point
print "           --> Should print 0.0"
# Out:
# Gradient single data point: 0.0
#            --> Should print 0.0

# %% [markdown]
# ## Modifying the derivative for using a batch of data points
#
# Stochastic gradient estimates the ascent direction using 1 data point, while gradient uses $N$ data points to decide how to update the the parameters. Another approach is to use to use a mini-batch of B≤N data points to estimate the ascent direction. This simple approach is faster than regular gradient but less noisy than a version of stochastic gradient that uses only 1 data point. In this notebook, we will use the batch technique, since the approach is very simple and will improve your results.
#
# Given a mini-batch (or a set of data points) $\mathbf{x}_{i}, \mathbf{x}_{i+1} \ldots \mathbf{x}_{i+B}$, the gradient function for this mini-batch of data points is given by:
# $$
# \color{red}{\sum_{s = i}^{i+B}} \frac{\partial\ell_{s}}{\partial w_j} = \color{red}{\sum_{s = i}^{i + B}} h_j(\mathbf{x}_s)\left(\mathbf{1}[y_s = +1] - P(y_s = +1 | \mathbf{x}_s, \mathbf{w})\right)
# $$
#
#
# **Computing the gradient for a "mini-batch" of data points**
#
# Using NumPy, we access the points $\mathbf{x}_i, \mathbf{x}_{i+1} \ldots \mathbf{x}_{i+B}$ in the training data using `feature_matrix_train[i:i+B,:]`
# and $y_i$ in the training data using `sentiment_train[i:i+B]`.
#
# We can compute $\color{red}{\sum_{s = i}^{i+B}} \partial\ell_{s}/\partial w_j$ easily as follows:

# %%
j = 1                        # Feature number
i = 10                       # Data point start
B = 10                       # Mini-batch size
coefficients = np.zeros(194) # A point w at which we are computing the gradient.

predictions = predict_probability(feature_matrix_train[i:i+B,:], coefficients)
indicator = (sentiment_train[i:i+B]==+1)

errors = indicator - predictions        
gradient_mini_batch = feature_derivative(errors, feature_matrix_train[i:i+B,j])
print "Gradient mini-batch data points: %s" % gradient_mini_batch
print "                --> Should print 1.0"
# Out:
# Gradient mini-batch data points: 1.0
#                 --> Should print 1.0

# %% [markdown]
# ### Averaging the gradient across a batch
#
# It is a common practice to normalize the gradient update rule by the batch size B:
#
# $$
# \frac{\partial\ell_{\color{red}{A}}(\mathbf{w})}{\partial w_j} \approx \color{red}{\frac{1}{B}} {\sum_{s = i}^{i + B}} h_j(\mathbf{x}_s)\left(\mathbf{1}[y_s = +1] - P(y_s = +1 | \mathbf{x}_s, \mathbf{w})\right)
# $$
# In other words, we update the coefficients using the **average gradient over data points** (instead of using a summation). By using the average gradient, we ensure that the magnitude of the gradient is approximately the same for all batch sizes. This way, we can more easily compare various batch sizes of stochastic gradient ascent (including a batch size of **all the data points**), and study the effect of batch size on the algorithm as well as the choice of step size.
#
#
# ## Implementing stochastic gradient ascent
#
# Now we are ready to implement our own logistic regression with stochastic gradient ascent. We complete the following function to fit a logistic regression model using gradient ascent:

# %%
def logistic_regression_SG(feature_matrix, sentiment, initial_coefficients, step_size, batch_size, max_iter):
    log_likelihood_all = []
    
    # make sure it's a numpy array
    coefficients = np.array(initial_coefficients)
    # set seed=1 to produce consistent results
    np.random.seed(seed=1)
    # Shuffle the data before starting
    permutation = np.random.permutation(len(feature_matrix))
    feature_matrix = feature_matrix[permutation,:]
    sentiment = sentiment[permutation]
    
    i = 0 # index of current batch
    # Do a linear scan over data
    for itr in xrange(max_iter):
        # Predict P(y_i = +1|x_i,w) using your predict_probability() function
        # Make sure to slice the i-th row of feature_matrix with [i:i+batch_size,:]
        ### YOUR CODE HERE
        predictions = predict_probability(feature_matrix[i:i+batch_size,:], coefficients)
        
        # Compute indicator value for (y_i = +1)
        # Make sure to slice the i-th entry with [i:i+batch_size]
        ### YOUR CODE HERE
        indicator = (sentiment[i:i+batch_size]==+1)
        
        # Compute the errors as indicator - predictions
        errors = indicator - predictions
        for j in xrange(len(coefficients)): # loop over each coefficient
            # Recall that feature_matrix[:,j] is the feature column associated with coefficients[j]
            # Compute the derivative for coefficients[j] and save it to derivative.
            # Make sure to slice the i-th row of feature_matrix with [i:i+batch_size,j]
            ### YOUR CODE HERE
            derivative = feature_derivative(errors, feature_matrix[i:i+batch_size,j])
            
            # compute the product of the step size, the derivative, and the **normalization constant** (1./batch_size)
            ### YOUR CODE HERE
            coefficients[j] += (1./batch_size)*(step_size * derivative)
        
        # Checking whether log likelihood is increasing
        # Print the log likelihood over the *current batch*
        lp = compute_avg_log_likelihood(feature_matrix[i:i+batch_size,:], sentiment[i:i+batch_size],
                                        coefficients)
        log_likelihood_all.append(lp)
        if itr <= 15 or (itr <= 1000 and itr % 100 == 0) or (itr <= 10000 and itr % 1000 == 0) \
         or itr % 10000 == 0 or itr == max_iter-1:
            data_size = len(feature_matrix)
            print 'Iteration %*d: Average log likelihood (of data points in batch [%0*d:%0*d]) = %.8f' % \
                (int(np.ceil(np.log10(max_iter))), itr, \
                 int(np.ceil(np.log10(data_size))), i, \
                 int(np.ceil(np.log10(data_size))), i+batch_size, lp)
        
        # if we made a complete pass over data, shuffle and restart
        i += batch_size
        if i+batch_size > len(feature_matrix):
            permutation = np.random.permutation(len(feature_matrix))
            feature_matrix = feature_matrix[permutation,:]
            sentiment = sentiment[permutation]
            i = 0
                
    # We return the list of log likelihoods for plotting purposes.
    return coefficients, log_likelihood_all

# %% [markdown]
# **Note**. In practice, the final set of coefficients is rarely used; it is better to use the average of the last K sets of coefficients instead, where K should be adjusted depending on how fast the log likelihood oscillates around the optimum.

# %% [markdown]
# ## Compare convergence behavior of stochastic gradient ascent
#
# For the remainder of the notebook, we will compare stochastic gradient ascent against batch gradient ascent. For this, we need a reference implementation of batch gradient ascent.

# %% [markdown]
# ## Running gradient ascent using the stochastic gradient ascent implementation

# %% [markdown]
# Instead of implementing batch gradient ascent separately, we save time by re-using the stochastic gradient ascent function we just wrote &mdash; **to perform gradient ascent**, it suffices to set **`batch_size`** to the number of data points in the training data.
#
# We now **run stochastic gradient ascent** over the **feature_matrix_train** for 10 iterations using:
# * `initial_coefficients = np.zeros(194)`
# * `step_size = 5e-1`
# * `batch_size = 1`
# * `max_iter = 10`

# %%
coefficients, log_likelihood = logistic_regression_SG(feature_matrix_train, sentiment_train,
                                        initial_coefficients=np.zeros(194),
                                        step_size=5e-1, batch_size=1, max_iter=10)
# Out:
# Iteration 0: Average log likelihood (of data points in batch [00000:00001]) = -0.07888973
# Iteration 1: Average log likelihood (of data points in batch [00001:00002]) = -0.05477862
# Iteration 2: Average log likelihood (of data points in batch [00002:00003]) = -0.00010090
# Iteration 3: Average log likelihood (of data points in batch [00003:00004]) = -0.00032919
# Iteration 4: Average log likelihood (of data points in batch [00004:00005]) = -0.02336450
# Iteration 5: Average log likelihood (of data points in batch [00005:00006]) = 0.00000000
# Iteration 6: Average log likelihood (of data points in batch [00006:00007]) = -0.57637255
# Iteration 7: Average log likelihood (of data points in batch [00007:00008]) = -0.09367112
# Iteration 8: Average log likelihood (of data points in batch [00008:00009]) = -0.04519316
# Iteration 9: Average log likelihood (of data points in batch [00009:00010]) = -0.12692692

# %% [markdown]
# Now run **batch gradient ascent** over the **feature_matrix_train** for 200 iterations using:
# * `initial_coefficients = np.zeros(194)`
# * `step_size = 5e-1`
# * `batch_size = len(feature_matrix_train)`
# * `max_iter = 200`

# %%
coefficients_batch, log_likelihood_batch = logistic_regression_SG(feature_matrix_train, sentiment_train,
                                        initial_coefficients=np.zeros(194),
                                        step_size=5e-1, 
                                        batch_size = len(feature_matrix_train), 
                                        max_iter=100)
# Out:
# Iteration  0: Average log likelihood (of data points in batch [00000:45022]) = -0.68266013
# Iteration  1: Average log likelihood (of data points in batch [00000:45022]) = -0.67322876
# Iteration  2: Average log likelihood (of data points in batch [00000:45022]) = -0.66459500
# Iteration  3: Average log likelihood (of data points in batch [00000:45022]) = -0.65664159
# Iteration  4: Average log likelihood (of data points in batch [00000:45022]) = -0.64928809
# Iteration  5: Average log likelihood (of data points in batch [00000:45022]) = -0.64246873
# Iteration  6: Average log likelihood (of data points in batch [00000:45022]) = -0.63612701
# Iteration  7: Average log likelihood (of data points in batch [00000:45022]) = -0.63021379
# Iteration  8: Average log likelihood (of data points in batch [00000:45022]) = -0.62468614
# Iteration  9: Average log likelihood (of data points in batch [00000:45022]) = -0.61950646
# Iteration 10: Average log likelihood (of data points in batch [00000:45022]) = -0.61464177
# Iteration 11: Average log likelihood (of data points in batch [00000:45022]) = -0.61006301
# Iteration 12: Average log likelihood (of data points in batch [00000:45022]) = -0.60574455
# Iteration 13: Average log likelihood (of data points in batch [00000:45022]) = -0.60166371
# Iteration 14: Average log likelihood (of data points in batch [00000:45022]) = -0.59780035
# Iteration 15: Average log likelihood (of data points in batch [00000:45022]) = -0.59413656
# Iteration 99: Average log likelihood (of data points in batch [00000:45022]) = -0.49430360

# %% [markdown]
# ## Make "passes" over the dataset

# %% [markdown]
# To make a fair comparison betweeen stochastic gradient ascent and batch gradient ascent, we measure the average log likelihood as a function of the number of passes (defined as follows):
# $$
# [\text{# of passes}] = \frac{[\text{# of data points touched so far}]}{[\text{size of dataset}]}
# $$

# %% [markdown]
# ## Log likelihood plots for stochastic gradient ascent

# %% [markdown]
# With the terminology in mind, let us run stochastic gradient ascent for 10 passes. We will use
# * `step_size=1e-1`
# * `batch_size=100`
# * `initial_coefficients` to all zeros.

# %%
step_size = 1e-1
batch_size = 100
num_passes = 10
num_iterations = num_passes * int(len(feature_matrix_train)/batch_size)

coefficients_sgd, log_likelihood_sgd = logistic_regression_SG(feature_matrix_train, sentiment_train,
                                       initial_coefficients=np.zeros(194),
                                       step_size=1e-1, batch_size=100, max_iter=num_iterations)
# Out:
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -0.68434532
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -0.67533643
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -0.67594278
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -0.65921516
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -0.67510933
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -0.68484827
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -0.67688983
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -0.68115164
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -0.67626365
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -0.66678259
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -0.67592974
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -0.66633147
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -0.67421179
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -0.65558546
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -0.65654977
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -0.66255872
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -0.55618185
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -0.56368138
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -0.52734690
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -0.51828190
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -0.49553480
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -0.46718294
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -0.52432998
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -0.41017945
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -0.47256610
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -0.46804577
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -0.44894446
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -0.40952869
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -0.46895530
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -0.51237940

# %% [markdown]
# We use a utility function to plot the average log likelihood as a function of the number of passes:

# %%
def make_plot(log_likelihood_all, len_data, batch_size, smoothing_window=1, label=''):
    plt.rcParams.update({'figure.figsize': (9,5)})
    log_likelihood_all_ma = np.convolve(np.array(log_likelihood_all), \
                                        np.ones((smoothing_window,))/smoothing_window, mode='valid')
    plt.plot(np.array(range(smoothing_window-1, len(log_likelihood_all)))*float(batch_size)/len_data,
             log_likelihood_all_ma, linewidth=4.0, label=label)
    plt.rcParams.update({'font.size': 16})
    plt.tight_layout()
    plt.xlabel('# of passes over data')
    plt.ylabel('Average log likelihood per data point')
    plt.legend(loc='lower right', prop={'size':14})

# %%
make_plot(log_likelihood_sgd, len_data=len(feature_matrix_train), batch_size=100,
          label='stochastic gradient, step_size=1e-1')

# %% [markdown]
# ## Smoothing the stochastic gradient ascent curve
#
# The plotted line oscillates so much that it is hard to see whether the log likelihood is improving. In our plot, we apply a simple smoothing operation using the parameter `smoothing_window`. The smoothing is simply a [moving average](https://en.wikipedia.org/wiki/Moving_average) of log likelihood over the last `smoothing_window` "iterations" of  stochastic gradient ascent.

# %%
make_plot(log_likelihood_sgd, len_data=len(feature_matrix_train), batch_size=100,
          smoothing_window=30, label='stochastic gradient, step_size=1e-1')

# %% [markdown]
# **Checkpoint**: The above plot should look smoother than the previous plot. Play around with `smoothing_window`. As you increase it, you should see a smoother plot.

# %% [markdown]
# ## Stochastic gradient ascent vs batch gradient ascent
#
# To compare convergence rates for stochastic gradient ascent with batch gradient ascent, we call `make_plot()` multiple times in the same cell.
#
# We are comparing:
# * **stochastic gradient ascent**: `step_size = 0.1`, `batch_size=100`
# * **batch gradient ascent**: `step_size = 0.5`, `batch_size=len(feature_matrix_train)`
#
# Write code to run stochastic gradient ascent for 200 passes using:
# * `step_size=1e-1`
# * `batch_size=100`
# * `initial_coefficients` to all zeros.

# %%
step_size = 1e-1
batch_size = 100
num_passes = 200
num_iterations = num_passes * int(len(feature_matrix_train)/batch_size)

coefficients_sgd, log_likelihood_sgd = logistic_regression_SG(feature_matrix_train, sentiment_train,
                                       initial_coefficients=np.zeros(194),
                                       step_size=step_size, batch_size=batch_size, max_iter=num_iterations)
# Out:
# Iteration     0: Average log likelihood (of data points in batch [00000:00100]) = -0.68434532
# Iteration     1: Average log likelihood (of data points in batch [00100:00200]) = -0.67533643
# Iteration     2: Average log likelihood (of data points in batch [00200:00300]) = -0.67594278
# Iteration     3: Average log likelihood (of data points in batch [00300:00400]) = -0.65921516
# Iteration     4: Average log likelihood (of data points in batch [00400:00500]) = -0.67510933
# Iteration     5: Average log likelihood (of data points in batch [00500:00600]) = -0.68484827
# Iteration     6: Average log likelihood (of data points in batch [00600:00700]) = -0.67688983
# Iteration     7: Average log likelihood (of data points in batch [00700:00800]) = -0.68115164
# Iteration     8: Average log likelihood (of data points in batch [00800:00900]) = -0.67626365
# Iteration     9: Average log likelihood (of data points in batch [00900:01000]) = -0.66678259
# Iteration    10: Average log likelihood (of data points in batch [01000:01100]) = -0.67592974
# Iteration    11: Average log likelihood (of data points in batch [01100:01200]) = -0.66633147
# Iteration    12: Average log likelihood (of data points in batch [01200:01300]) = -0.67421179
# Iteration    13: Average log likelihood (of data points in batch [01300:01400]) = -0.65558546
# Iteration    14: Average log likelihood (of data points in batch [01400:01500]) = -0.65654977
# Iteration    15: Average log likelihood (of data points in batch [01500:01600]) = -0.66255872
# Iteration   100: Average log likelihood (of data points in batch [10000:10100]) = -0.55618185
# Iteration   200: Average log likelihood (of data points in batch [20000:20100]) = -0.56368138
# Iteration   300: Average log likelihood (of data points in batch [30000:30100]) = -0.52734690
# Iteration   400: Average log likelihood (of data points in batch [40000:40100]) = -0.51828190
# Iteration   500: Average log likelihood (of data points in batch [05000:05100]) = -0.49553480
# Iteration   600: Average log likelihood (of data points in batch [15000:15100]) = -0.46718294
# Iteration   700: Average log likelihood (of data points in batch [25000:25100]) = -0.52432998
# Iteration   800: Average log likelihood (of data points in batch [35000:35100]) = -0.41017945
# Iteration   900: Average log likelihood (of data points in batch [00000:00100]) = -0.47256610
# Iteration  1000: Average log likelihood (of data points in batch [10000:10100]) = -0.46804577
# Iteration  2000: Average log likelihood (of data points in batch [20000:20100]) = -0.44894446
# Iteration  3000: Average log likelihood (of data points in batch [30000:30100]) = -0.40952869
# Iteration  4000: Average log likelihood (of data points in batch [40000:40100]) = -0.46895530
# Iteration  5000: Average log likelihood (of data points in batch [05000:05100]) = -0.50596031
# Iteration  6000: Average log likelihood (of data points in batch [15000:15100]) = -0.51027056
# Iteration  7000: Average log likelihood (of data points in batch [25000:25100]) = -0.42625446
# Iteration  8000: Average log likelihood (of data points in batch [35000:35100]) = -0.38990046
# Iteration  9000: Average log likelihood (of data points in batch [00000:00100]) = -0.41864723
# Iteration 10000: Average log likelihood (of data points in batch [10000:10100]) = -0.39313188
# Iteration 20000: Average log likelihood (of data points in batch [20000:20100]) = -0.47738941
# Iteration 30000: Average log likelihood (of data points in batch [30000:30100]) = -0.46774437
# Iteration 40000: Average log likelihood (of data points in batch [40000:40100]) = -0.57450276
# Iteration 50000: Average log likelihood (of data points in batch [05000:05100]) = -0.53559365
# Iteration 60000: Average log likelihood (of data points in batch [15000:15100]) = -0.35007565
# Iteration 70000: Average log likelihood (of data points in batch [25000:25100]) = -0.50671071
# Iteration 80000: Average log likelihood (of data points in batch [35000:35100]) = -0.47048286
# Iteration 89999: Average log likelihood (of data points in batch [44900:45000]) = -0.39861863

# %% [markdown]
# We compare the convergence of stochastic gradient ascent and batch gradient ascent in the following cell. Note that we apply smoothing with `smoothing_window=30`.

# %%
make_plot(log_likelihood_sgd, len_data=len(feature_matrix_train), batch_size=100,
          smoothing_window=30, label='stochastic, step_size=1e-1')
make_plot(log_likelihood_batch, len_data=len(feature_matrix_train), batch_size=len(feature_matrix_train),
          smoothing_window=1, label='batch, step_size=5e-1')

# %% [markdown]
# ## Explore the effects of step sizes on stochastic gradient ascent

# %% [markdown]
# We now explore a wide range of step sizes that are equally spaced in the log space. Run stochastic gradient ascent with `step_size` set to 1e-4, 1e-3, 1e-2, 1e-1, 1e0, 1e1, and 1e2. Use the following set of parameters:
# * `initial_coefficients=np.zeros(194)`
# * `batch_size=100`
# * `max_iter` initialized so as to run 10 passes over the data.

# %%
batch_size = 100
num_passes = 10
num_iterations = num_passes * int(len(feature_matrix_train)/batch_size)

coefficients_sgd = {}
log_likelihood_sgd = {}
for step_size in np.logspace(-4, 2, num=7):
    coefficients_sgd[step_size], log_likelihood_sgd[step_size] = logistic_regression_SG(feature_matrix_train, sentiment_train,
                                       initial_coefficients=np.zeros(194),
                                       step_size=step_size, batch_size=batch_size, max_iter=num_iterations)
# Out:
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -0.69313823
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -0.69312914
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -0.69312770
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -0.69310555
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -0.69312424
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -0.69314054
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -0.69312429
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -0.69313476
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -0.69313052
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -0.69311815
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -0.69312336
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -0.69311013
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -0.69313130
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -0.69309768
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -0.69310853
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -0.69310771
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -0.69290053
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -0.69263125
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -0.69273682
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -0.69220622
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -0.69218416
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -0.69173132
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -0.69193740
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -0.69101508
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -0.69181476
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -0.69104579
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -0.68927026
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -0.68730225
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -0.68618874
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -0.68460090
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -0.69305772
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -0.69296675
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -0.69295255
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -0.69273172
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -0.69291837
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -0.69308071
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -0.69291935
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -0.69302313
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -0.69298063
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -0.69285735
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -0.69290998
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -0.69277822
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -0.69298813
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -0.69265414
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -0.69276106
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -0.69275409
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -0.69069724
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -0.68816505
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -0.68906926
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -0.68434688
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -0.68416707
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -0.67981889
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -0.68111902
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -0.67285409
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -0.67955756
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -0.67477938
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -0.66073891
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -0.64131636
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -0.63310232
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -0.63866749
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -0.69225389
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -0.69134474
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -0.69122277
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -0.68907378
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -0.69091330
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -0.69247124
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -0.69096845
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -0.69191871
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -0.69148453
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -0.69029524
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -0.69087210
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -0.68960109
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -0.69152518
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -0.68839509
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -0.68931592
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -0.68935984
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -0.67014624
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -0.65528277
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -0.65578228
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -0.63377436
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -0.63130192
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -0.60269385
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -0.60619936
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -0.56435184
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -0.59666295
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -0.59044177
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -0.54581248
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -0.49637973
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -0.51995092
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -0.54487403
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -0.68434532
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -0.67533643
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -0.67594278
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -0.65921516
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -0.67510933
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -0.68484827
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -0.67688983
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -0.68115164
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -0.67626365
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -0.66678259
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -0.67592974
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -0.66633147
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -0.67421179
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -0.65558546
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -0.65654977
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -0.66255872
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -0.55618185
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -0.56368138
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -0.52734690
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -0.51828190
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -0.49553480
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -0.46718294
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -0.52432998
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -0.41017945
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -0.47256610
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -0.46804577
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -0.44894446
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -0.40952869
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -0.46895530
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -0.51237940
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -0.61790605
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -0.55960563
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -0.60247792
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -0.53549136
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -0.60669744
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -0.56852101
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -0.58408124
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -0.59768725
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -0.57045992
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -0.53817865
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -0.58624233
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -0.56319968
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -0.55538569
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -0.50695543
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -0.48811950
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -0.54456295
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -0.39135540
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -0.48103712
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -0.42510135
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -0.44872736
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -0.37511281
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -0.39804391
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -0.48813894
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -0.32572309
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -0.40739729
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -0.43922822
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -0.42800747
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -0.37246296
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -0.42561288
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -0.46275059
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -0.55911388
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -3.76680005
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -0.61401392
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -0.64855244
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -0.98303522
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -2.48544909
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -2.59445799
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -1.89552273
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -1.23198191
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -1.19054389
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -2.74370438
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -1.18924828
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -1.19357274
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -0.62587137
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -0.33875673
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -0.51861637
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -0.92745783
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -0.40785625
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -0.61237831
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -0.59282030
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -0.36760612
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -0.61416513
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -1.57858281
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -0.24959339
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -0.27396876
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -0.62613425
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -0.39032246
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -0.53530505
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -0.90221191
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -2.22003422
# Iteration    0: Average log likelihood (of data points in batch [00000:00100]) = -3.61398985
# Iteration    1: Average log likelihood (of data points in batch [00100:00200]) = -49.87163915
# Iteration    2: Average log likelihood (of data points in batch [00200:00300]) = -12.75168122
# Iteration    3: Average log likelihood (of data points in batch [00300:00400]) = -16.60912761
# Iteration    4: Average log likelihood (of data points in batch [00400:00500]) = -22.74393385
# Iteration    5: Average log likelihood (of data points in batch [00500:00600]) = -22.12467909
# Iteration    6: Average log likelihood (of data points in batch [00600:00700]) = -28.42785881
# Iteration    7: Average log likelihood (of data points in batch [00700:00800]) = -14.15326889
# Iteration    8: Average log likelihood (of data points in batch [00800:00900]) = -11.30148314
# Iteration    9: Average log likelihood (of data points in batch [00900:01000]) = -10.76175167
# Iteration   10: Average log likelihood (of data points in batch [01000:01100]) = -21.65895997
# Iteration   11: Average log likelihood (of data points in batch [01100:01200]) = -9.69699657
# Iteration   12: Average log likelihood (of data points in batch [01200:01300]) = -10.74476847
# Iteration   13: Average log likelihood (of data points in batch [01300:01400]) = -4.62127987
# Iteration   14: Average log likelihood (of data points in batch [01400:01500]) = -1.91604134
# Iteration   15: Average log likelihood (of data points in batch [01500:01600]) = -3.26081896
# Iteration  100: Average log likelihood (of data points in batch [10000:10100]) = -10.57530067
# Iteration  200: Average log likelihood (of data points in batch [20000:20100]) = -2.98075706
# Iteration  300: Average log likelihood (of data points in batch [30000:30100]) = -10.12444850
# /home/ian/venv/lib/python2.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in exp
#   """
# /home/ian/venv/lib/python2.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in exp
#   # Remove the CWD from sys.path while we load stuff.
# Iteration  400: Average log likelihood (of data points in batch [40000:40100]) = -5.34412307
# Iteration  500: Average log likelihood (of data points in batch [05000:05100]) = -2.92170684
# Iteration  600: Average log likelihood (of data points in batch [15000:15100]) = -2.81345499
# Iteration  700: Average log likelihood (of data points in batch [25000:25100]) = -23.03289528
# Iteration  800: Average log likelihood (of data points in batch [35000:35100]) = -1.50252877
# Iteration  900: Average log likelihood (of data points in batch [00000:00100]) = -1.55123850
# Iteration 1000: Average log likelihood (of data points in batch [10000:10100]) = -4.30504990
# Iteration 2000: Average log likelihood (of data points in batch [20000:20100]) = -2.29177914
# Iteration 3000: Average log likelihood (of data points in batch [30000:30100]) = -6.02916080
# Iteration 4000: Average log likelihood (of data points in batch [40000:40100]) = -5.91022351
# Iteration 4499: Average log likelihood (of data points in batch [44900:45000]) = -26.90132006

# %% [markdown]
# ### Plotting the log likelihood as a function of passes for each step size
#
# Now, we will plot the change in log likelihood using the `make_plot` for each of the following values of `step_size`:
#
# * `step_size = 1e-4`
# * `step_size = 1e-3`
# * `step_size = 1e-2`
# * `step_size = 1e-1`
# * `step_size = 1e0`
# * `step_size = 1e1`
# * `step_size = 1e2`

# %% [markdown]
# For consistency, we again apply `smoothing_window=30`.

# %%
for step_size in np.logspace(-4, 2, num=7):
    make_plot(log_likelihood_sgd[step_size], len_data=len(train_data), batch_size=100,
              smoothing_window=30, label='step_size=%.1e'%step_size)

# %% [markdown]
# Now, let us remove the step size `step_size = 1e2` and plot the rest of the curves.

# %%
for step_size in np.logspace(-4, 2, num=7)[0:6]:
    make_plot(log_likelihood_sgd[step_size], len_data=len(train_data), batch_size=100,
              smoothing_window=30, label='step_size=%.1e'%step_size)

# %% [markdown]
# We have now implemented a logistic regression with stochastic gradient ascent from scratch! In addition, we investigated the effect of step_size on convergence properties. I hope you found this helpful and instructive!
